# %%
bronze_df = spark.table(
    "career_os.bronze.jobs_raw"
)
display(bronze_df)

# %%
from pyspark.sql.functions import (
    col,
    trim,
    regexp_replace,
    concat_ws,
    length,
    current_timestamp
)


silver_df = (
    bronze_df
    .withColumn(
        "clean_description",
        trim(
            regexp_replace(
                col("description"),
                "\\s+",
                " "
            )
        )
    )
)

# %%
silver_df = silver_df.withColumn(
    "search_text",
    concat_ws(
        " ",
        col("title"),
        col("company"),
        col("clean_description")
    )
)

# %%
silver_df = silver_df.withColumn(
    "description_length",
    length(col("clean_description"))
)

# %%
silver_df.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable(
        "career_os.silver.jobs_clean"
    )
